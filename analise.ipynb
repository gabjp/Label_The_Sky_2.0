# %%
import numpy as np
# QSO[PRECIOSION RECALL FSCORE], STAR[PRECIOSION RECALL FSCORE], GAL[PRECIOSION RECALL FSCORE], acc, fmean
##################### NO WISE FEATURES#########################
#WITH_WISE DATA:
ww_run1 = [0.959147 , 0.861244 , 0.907563,0.964236 , 0.979245 , 0.971683,0.973400 , 0.984369 , 0.978854,0.968352, 0.952700 ]
ww_run2 = [0.957672 , 0.866029 , 0.909548, 0.965068 , 0.977358 , 0.971174 ,0.973060 , 0.984733 , 0.978862 ,0.968352, 0.953195]
ww_run3 = [0.959790 , 0.875598 , 0.915763, 0.966449,  0.978302,  0.972339, 0.973741 , 0.984006 , 0.978847, 0.969443, 0.955650]
#NO_WISE DATA:
nw_run1 = [0.693931 , 0.952899 , 0.803053, 0.976238,  0.818937,  0.890696, 0.874539,  0.855596,  0.864964, 0.859740, 0.852904]
nw_run2 = [0.688482,  0.952899,  0.799392, 0.970414,  0.817276,  0.887286, 0.883459,  0.848375,  0.865562, 0.857143, 0.850747]
nw_run3 = [0.687500,  0.956522,  0.800000, 0.978218,  0.820598,  0.892502, 0.890977,  0.855596,  0.872928, 0.861472, 0.855143]

ww = np.array([ww_run1, ww_run2, ww_run3])*100
nw = np.array([nw_run1, nw_run2, nw_run3])*100

ww_mean = np.mean(ww, axis=0)
ww_std = np.std(ww, axis=0)

nw_mean = np.mean(nw, axis=0)
nw_std = np.std(nw, axis=0)

# %%
################### ONLY WISE FEATURES ##################
run1 = [0.953968 , 0.958533 , 0.956245, 0.997136,  0.985377,  0.991222, 0.981608,  0.989458,  0.985518, 0.984358, 0.977662]
run2 = [0.957075 , 0.960128 , 0.958599, 0.996660,  0.985377,  0.990987, 0.981969,  0.989822,  0.985880, 0.984722, 0.978488]
run3 = [0.952532,  0.960128,  0.956315, 0.996659,  0.984906,  0.990747, 0.981595,  0.988731,  0.985150,  0.983994, 0.977404]

ww = np.array([run1, run2, run3])*100

ww_mean = np.mean(ww, axis=0)
ww_std = np.std(ww, axis=0)

# %%
################# UNIFIED ###################################

ww_run1 = [0.949527,  0.960128,  0.954798, 0.997612,  0.985377,  0.991457, 0.981588,  0.988368,  0.984966, 0.983994, 0.977074]
ww_run2 = [0.952607,  0.961722,  0.957143, 0.996183,  0.984906,  0.990512, 0.981943,  0.988368,  0.985145, 0.983994, 0.977600]
ww_run3 = [0.951411,  0.968102,  0.959684, 0.997612,  0.985377,  0.991457, 0.983008,  0.988368,  0.985681, 0.984904, 0.978940]

nw_run1 = [0.763578,  0.865942,  0.811545, 0.921368,  0.895349,  0.908172, 0.910506,  0.844765,  0.876404, 0.876190, 0.865374]
nw_run2 = [0.761006,  0.876812,  0.814815, 0.928571,  0.885382,  0.906463, 0.897338,  0.851986,  0.874074, 0.875325, 0.865117]
nw_run3 = [0.778135,  0.876812,  0.824532, 0.931271,  0.900332,  0.915541, 0.912214,  0.862816,  0.886827, 0.885714, 0.875633]

ww = np.array([ww_run1, ww_run2, ww_run3])*100
nw = np.array([nw_run1, nw_run2, nw_run3])*100

ww_mean = np.mean(ww, axis=0)
ww_std = np.std(ww, axis=0)

nw_mean = np.mean(nw, axis=0)
nw_std = np.std(nw, axis=0)

# %%
nw_std
# Out:
# array([0.75419131, 0.51241671, 0.55153841, 0.41798806, 0.62153384,
#        0.39388792, 0.66467107, 0.74182234, 0.55448358, 0.4706805 ,
#        0.48978384])
